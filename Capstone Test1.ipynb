# %%
import sys
sys.version
# Out:
# '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]'

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
# %matplotlib inline

# %%
img = Image.open("Desktop/picA.jpg")
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-23fc3dac1377> in <module>
# ----> 1 img = Image.open("Desktop/picA.jpg")
#       2 img
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/picA.jpg'

# %%
#insert image method 2
from PIL import Image
img =Image.open("picA.jpg", mode= "r")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x539 at 0x2BE58C9EC88>
